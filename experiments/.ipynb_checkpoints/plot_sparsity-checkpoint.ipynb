# %%
using LinearAlgebra
using Plots

# %%
DUMP_DIR = joinpath(@__DIR__, "..", "dump", "sparsity")
NNSDP_PATH = joinpath(@__DIR__, "..", "src", "NnSdp.jl")
include(NNSDP_PATH); using .NnSdp

# %%
# colors = theme_palette(:auto)
colors = palette(:tab10)

xdims = [3;3;3;3;3;3;3]
ffnet = randomNetwork(xdims)
zdims = ffnet.zdims
N = sum(zdims[1:end-1])
K = ffnet.K

S(k) = sum(ffnet.xdims[1:k])

E1 = E(1, ffnet.zdims)
EK = E(K, ffnet.zdims)
Ea = E(K+1, ffnet.zdims)
Ein = [E1; Ea]
Eout = [E1; EK; Ea]
;

# %%
hots(X) = map(x -> (x != 0), X)

function quickEM(beta)
  Z = zeros(N+1, N+1)
  for k = 1:K-1
    for i = 1:N
      for j = 1:N
        Z[i,j] += ((S(k-1)+1 <= i <= S(k+1)+beta)
                && (S(k-1)+1 <= j <= S(k+1)+beta))
      end
    end
  end
  return hots(Z)
end

function quickE1K()
  Z = zeros(N+1, N+1)
  for i in 1:N
    for j in 1:N
      Z[i,j] += ((1 <= i <= xdims[1] && S(K-1)+1 <= j <= N)
               || (1 <= j <= xdims[1] && S(K-1)+1 <= i <= N))
    end
  end
  return hots(Z)
end

function quickEK()
  Z = zeros(N+1, N+1)
  for i in 1:N
    for j in 1:N
      Z[i,j] += (S(K-1)+1 <= j <= N) || (S(K-1)+1 <= i <= N)
    end
  end
  return hots(Z)
end

function quickEa()
  Z = zeros(N+1, N+1)
  for i in 1:N+1
    for j in 1:N+1
      Z[i,j] += (i == N+1) || (j == N+1)
    end
  end
  return hots(Z)
end

function quickRawZ(beta)
  return quickEM(beta) + quickE1K() + quickEa()
end
# Out:
# quickRawZ (generic function with 1 method)

# %%
beta = 0
plt = spy(quickEM(beta), marker=(:square, 8.0, colors[1]), axis=([], true))
spy!(quickE1K(), marker=(:square, 8.0, colors[2]), axis=([], true))
spy!(quickEa(), marker=(:square, 8.0, colors[3]), axis=([], true))

# %%
saveto = joinpath(DUMP_DIR, "Zrawbeta$(beta).png")
savefig(plt, saveto)

# %%
beta = 2
plt = spy(quickEM(beta), marker=(:square, 8.0, colors[1]), axis=([], true))
spy!(quickE1K(), marker=(:square, 8.0, colors[2]), axis=([], true))
spy!(quickEa(), marker=(:square, 8.0, colors[3]), axis=([], true))

# %%
saveto = joinpath(DUMP_DIR, "Zrawbeta$(beta).png")
savefig(plt, saveto)

# %%
beta = 4
plt = spy(quickEM(beta), marker=(:square, 8.0, colors[1]), axis=([], true))
spy!(quickE1K(), marker=(:square, 8.0, colors[2]), axis=([], true))
spy!(quickEa(), marker=(:square, 8.0, colors[3]), axis=([], true))

# %%
saveto = joinpath(DUMP_DIR, "Zrawbeta$(beta).png")
savefig(plt, saveto)

# %%
beta = 0

plt = spy(quickEK(),
  marker = (:star5, 8.0, "red"),
  azis=([], true)
)

plt = spy!(plt, quickRawZ(beta),
  marker = (:square, 8.0, "gray"),
  axis=([], true),
)

# %%
saveto = joinpath(DUMP_DIR, "Zbeta$(beta).png")
savefig(plt, saveto)

# %%
beta = 2

plt = spy(quickEK(),
  marker = (:star5, 8.0, "red"),
  azis=([], true)
)

plt = spy!(plt, quickRawZ(beta),
  marker = (:square, 8.0, "gray"),
  axis=([], true),
)

# %%
saveto = joinpath(DUMP_DIR, "Zbeta$(beta).png")
savefig(plt, saveto)

# %%
beta = 4

plt = spy(quickEK(),
  marker = (:star5, 8.0, "red"),
  azis=([], true)
)

plt = spy!(plt, quickRawZ(beta),
  marker = (:square, 8.0, "gray"),
  axis=([], true),
)

# %%
saveto = joinpath(DUMP_DIR, "Zbeta$(beta).png")
savefig(plt, saveto)
